# %%
#Libraries used
import pandas as pd
import nltk
import re
from unidecode import unidecode
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import TweetTokenizer
from nltk.tokenize import sent_tokenize 
from nltk.corpus import stopwords

# %%
""" Needed for some functions in class """

#To stop_words
stop_words = set(stopwords.words('english'))

#Word_corpus
words_corp = set(nltk.corpus.words.words())


#regex dict contains regex identification of word which need to be replced with an specific word, in oreder to remove noise, contractions or special words.
regex_dict = {'phone': ('\+[0-9]{12}','phone'), 'email':('regex','e-mail'), 'good': ('goo[o]*d[d]*','good'),
              'bad': ('ba[a]*d[d]*','bad'), 'sad': ('sa[a]*d[d]*','sad'), 'url': ('@^(https?|ftp)://[^\s/$.?#].[^\s]*$@iS','url'),
             'not': ("n\'t"," not"), 'are':("\'re", " are"), 'is':("\'s", " is"), 'would': ("\'d", " would"),
             'will': ("\'ll", " will"), 'have':("\'ve", " have"), 'am': ("\'m", " am"), 'int': ('\w*\d\w*', ''), 'n': ("\'n", '')}

# %%
class Preprocessor:
    def __init__(self,tweet_text):
        self.string = tweet_text.lower()  # Self.string referring to the string(tweet) using for all functions.
    
    def stemWords(self):
        ps = PorterStemmer()  #Steammer
        roots=[]
        
        for word in self.string.split(" "):
            roots.append(ps.stem(word))
        stemmed = ' '.join(roots)  #String with all words root
        self.string = stemmed
        return self.string
    
    
    def lemWords(self):
        lm = WordNetLemmatizer()  #Lemmatizer
        lem_words = []
        
        for word in self.string.split(" "):
            lem_words.append(lm.lemmatize(word,pos='a'))
        lematized = ' '.join(lem_words)  #String with all lemmatized words
        self.string = lematized
        return self.string
    
    
    def stopWords(self):
        new_sentence = []
        for word in self.string.split(" "):
            if word not in stop_words:   #Removing stopwords
                new_sentence.append(word)
            else: continue
        cleaned = ' '.join(new_sentence)  #Str without stopw
        self.string = cleaned
        return cleaned
    
    def removeNoise(self):
        first_clear=[]
        for w in self.string.split(" "):
            #isalnum for removing punctuation and endwith to take into account verbs in 3rd person
            if w.isalnum() and len(w)>1 and (w in words_corp or w.endswith('s')):
                first_clear.append(w)
        clean = ' '.join(first_clear)
        self.string = unidecode(clean) #Unicode to remove accents and simbols over letters
        return self.string
    
    
    def wordTokenize(self):
        #Twitter tokenizer was used to consider emojis, hastags and user names while tokenizing
        tt = TweetTokenizer(strip_handles=True, reduce_len=True)
        tokenized = ' '.join(tt.tokenize(self.string))
        self.string = tokenized
        return self.string
        
    
    def phraseTokenize(self):
        # Sent_tokenize help to tokenize str by sentences
        sentt = sent_tokenize
        cleaned =' '.join(sentt(self.string))
        self.string = cleaned
        return self.string
    
    
    def extractRegex(self,regex_dict):
        txt = self.string
        for regx,rep_name in list(regex_dict.values()):  #When a regex in dict cmatch with a word, that words is replaced with rgx name_value
            txt = re.sub(regx,rep_name,txt)
        self.string = txt 
        return self.string

# %% [markdown]
# ***TESTING IT***

# %%
df = pd.read_csv('tweets.csv',sep=",")

# %%
#imported data
df.head(2)
# Out:
#                                                tweet  senti
# 0  @united Oh, we are sure it's not planned, but ...      0
# 1                          History exam studying ugh      0

# %%
#Calling class' functions for all tweets
new_tweets = {}
count = 0
for tweet,senti in zip(df['tweet'],df['senti']):
    tw = Preprocessor(tweet)
    tw.phraseTokenize()
    tw.wordTokenize()
    tw.extractRegex(regex_dict)
    tw.removeNoise()
    tw.stopWords()
    tw.lemWords()
    final_tw = tw.stemWords()
    new_tweets[count] = (final_tw,senti)
    count+=1

# %%
#Dict of prepocessed tweets
new_tweets
# Out:
# {0: ('oh sure occur absolut consist usual flight daili', 0),
#  1: ('histori exam ugh', 0),
#  2: ('yeah look like busi yeah', 0),
#  3: ('love twitter', 4),
#  4: ('realli dont want phone servic suck come signal', 0),
#  5: ('want either might get pilotless plane driverless car', 0),
#  6: ('super cool next stop road car', 4),
#  7: ('aw night end badli', 0),
#  8: ('lot buzz lucki free', 4),
#  9: ('got new pair shoe pic late', 2),
#  10: ('hey chanc updat flight', 2),
#  11: ('learn book review', 2),
#  12: ('dentist great expens', 0),
#  13: ('love chocol milk yeah', 4),
#  14: ('oh good glad feel good realli good crazi week though good way', 4),
#  15: ('appl even bare anyth coupl featur got self drive car glass tango project ara',
#   2),
#  16: ('today rad made final cross countri love ps everythin cool mate', 4),
#  17: ('happi', 4),
#  18: ('night museum wolverin junk food perfect', 4),
#  19: ('say cut small talk new slogan give us money apolog bob', 0),
#  20: ('fight sever time week even bother', 0),
#  21: ('back work one word', 4),
#  22: ('say long time democrat base', 2),
#  23: ('could cabl suck', 0),
#  24: ('new car watch someth holi crap', 4),
#  25: ('hour delay noth say sorri like voucher miss time famili', 0),
#  26: ('entir colleg lost transcript ca attend summer catch credit', 0),
#  27: ('love kindl stack book trip way loo', 4),
#  28: ('look avail kindl kindl get top electron book reader period free day ship',
#   2),
#  29: ('time warner cabl pull plug experi', 2),
#  30: ('shaun grandpar get around slow text tweet stop', 0),
#  31: ('alreadi self drive car road wait govern', 2),
#  32: ('primari debit card visa electron', 2),
#  33: ('new post got new case', 2),
#  34: ('wish timothi dalton roger know', 0),
#  35: ('citi day happi home school morn', 4),
#  36: ('stay china never come back', 0),
#  37: ('time warner line crap', 0),
#  38: ('coincid stalk twitter feed news great thank', 4),
#  39: ('fail', 0),
#  40: ('love cattl dog stori', 4),
#  41: ('sound good wish could done determin find park good', 4),
#  42: ('go ahead live premium cabin heaven en rout', 4),
#  43: ('damn time warner', 0),
#  44: ('car take steer wheel away cold dead hand buy one', 0),
#  45: ('love much window look forward latex editor', 4),
#  46: ('asthma blow ca wait till finish treatment follow hope final apt week',
#   0),
#  47: ('click link want flight book flight yet read waiv fee militari true', 2),
#  48: ('watch highlight damn nigga good', 4),
#  49: ('dell batteri', 0),
#  50: ('thank class may min flight', 4),
#  51: ('hear driverless car come da peopl lazi seem danger hell', 0),
#  52: ('accident step power strip button internet', 0),
#  53: ('sent messag let know', 2),
#  54: ('read kindl love lee child good read', 4),
#  55: ('video first user self drive car lost vision well past legal blind', 4),
#  56: ('car hour joke went min go', 0),
#  57: ('old guy board stupid heck', 0),
#  58: ('jake go', 2),
#  59: ('glad hear great night rock hope tonight mani feel good show', 4),
#  60: ('sorri hear plan best staff servic countri', 4),
#  61: ('send us chevi photo', 2),
#  62: ('saw new night museum next go see', 4),
#  63: ('cool', 4),
#  64: ('cox time warner cox get dslreport expens get', 0),
#  65: ('oh god stomach growl', 0),
#  66: ('mean dame good school would close dan would enjoy', 4),
#  67: ('go meet get go home', 0),
#  68: ('excit come car', 4),
#  69: ('take see night museum pick', 2),
#  70: ('got back church total hate insect', 0),
#  71: ('popular among arab survey presid popular lead countri', 4),
#  72: ('car test amaz', 4),
#  73: ('blazer high custom brad dougla', 2),
#  74: ('high guy mail order bride', 0),
#  75: ('save money groceri store trip stock food hotel room vs eat everi night town',
#   2),
#  76: ('time warner problem', 0),
#  77: ('someday look nearli good next day look total today next day', 0),
#  78: ('oh look one self drive car freeway north', 2),
#  79: ('broke nail', 0),
#  80: ('flight fli way mind take ocean approach sleep', 2),
#  81: ('zydruna awesom duo', 4),
#  82: ('total believ driverless car averag driver', 4),
#  83: ('saw car outsid half hour east', 2),
#  84: ('twitter make crazi', 0),
#  85: ('ask latex link comment', 2),
#  86: ('hate', 0),
#  87: ('five thing wolfram alpha good vastli differ', 4),
#  88: ('kindl pr like physic devic feel good font nice turn snappi littl', 4),
#  89: ('someon never learn drive welcom car overlord', 4),
#  90: ('go ahead blow north map alreadi', 0),
#  91: ('took graduat field exam comput scienc today noth make feel like idiot lambda calculu',
#   0),
#  92: ('imagin world self drive car merg', 2),
#  93: ('di use last question ask driverless car wild card question', 2),
#  94: ('thank', 4),
#  95: ('hi saw talk realli advic say hi ye video get around', 4),
#  96: ('hate revis bore total unprepar exam tomorrow thing look good', 0),
#  97: ('well work thank', 0),
#  98: ('surgeri wish', 0),
#  99: ('world cup access damn good look', 4),
#  100: ('switch fli unit delta past two trip disappoint hour', 0),
#  101: ('twitter', 2),
#  102: ('pet dentist', 2),
#  103: ('china continu key partner', 2),
#  104: ('admit rather good year still got hook peac', 4),
#  105: ('total took chang sceneri great', 4),
#  106: ('thank time servic great staff get wife past week honeymoon', 4),
#  107: ('appreci follow', 4),
#  108: ('pleasantli find ana made major upgrad transpacif rout flight plane servic',
#   4),
#  109: ('call car warranti number wo fix call everi number', 0),
#  110: ('man tire night work hope get job got bout hill dang', 0),
#  111: ('give man fish feed day teach fish feed life buy good', 0),
#  112: ('wave develop sandbox account request', 2),
#  113: ('got free android phone confer', 4),
#  114: ('saw sunshin clean love ami adam', 4),
#  115: ('ugh need renew restrain order help', 0),
#  116: ('one would love herd someday', 4),
#  117: ('hack', 2),
#  118: ('bank holiday yet work exam season suck', 0),
#  119: ('appl decad support appl', 0),
#  120: ('san back hurt last night', 0),
#  121: ('car drove hope got', 0),
#  122: ('good riddanc sad though', 0),
#  123: ('expect radio morn', 2),
#  124: ('driverless golf cart', 2),
#  125: ('star trek good everyon said', 4),
#  126: ('guess retir start develop', 4),
#  127: ('upsid time warner unhelp phone oper servic crap upsid', 0),
#  128: ('highli recommend', 4),
#  129: ('love vitamin water commerci wish adida', 4),
#  130: ('like guy show funni side', 4),
#  131: ('holi high speed batman speed unit club insan fast thank', 4),
#  132: ('driverless car wast money get taxi', 0),
#  133: ('flight gate agent kerri la also excel job get destin today thank', 4),
#  134: ('oh oh found cloth love em', 4),
#  135: ('systemat run driverless car', 0),
#  136: ('still love kindl read new york time feel natur miss ad', 0),
#  137: ('unfortun stimulu plan put place twice help back peopl led inevit', 0),
#  138: ('love futurist stuff like also give self drive car face pretti geniu',
#   4),
#  139: ('blown away stellar thank', 4),
#  140: ('driverless car terribl anyon fan mean', 0),
#  141: ('last day work go holiday got load', 0),
#  142: ('test twitter', 2),
#  143: ('accept level risk new technolog realiti peopl die autonom car hard accept',
#   0),
#  144: ('listen amaz much', 4),
#  145: ('wo help done', 0),
#  146: ('also hour trip way past midnight extrem exhaust', 0),
#  147: ('care neighbor', 4),
#  148: ('hate dentist', 0),
#  149: ('upgrad price go pay someth thought', 0),
#  150: ('via mobil coupon', 2),
#  151: ('think peopl dislik buse glass wait till self drive car caus die crash',
#   0),
#  152: ('curs twitter limit', 0),
#  153: ('car want one', 4),
#  154: ('itchi miser', 0),
#  155: ('new post trainer', 2),
#  156: ('new post dunk low premium white gum', 2),
#  157: ('earli super crabbi want back bed pup wish home tonight bed', 0),
#  158: ('thank love unit flight today', 4),
#  159: ('alway good place look work mustang dad', 4),
#  160: ('still hungri eat', 2),
#  161: ('appli', 4),
#  162: ('back see star trek night museum star trek amaz night museum eh', 0),
#  163: ('ah skin itchi damn', 0),
#  164: ('sigh wish could meet san spoke alreadi said great', 4),
#  165: ('watch night museum giggl', 4),
#  166: ('got hord insect hungri kitchen light scari', 0),
#  167: ('car sound good headlin okay driverless car', 4),
#  168: ('mayb put danc step use today confer', 2),
#  169: ('good', 4),
#  170: ('night museum pretti good', 4),
#  171: ('yeah right cast accident fall love right', 4),
#  172: ('read bill fail win', 4),
#  173: ('amaz realli', 4),
#  174: ('adopt child bitten wasp gave', 2),
#  175: ('plan build car steer wheel', 2),
#  176: ('dear appl bad servic ever', 0),
#  177: ('real good moment misss much', 4),
#  178: ('math review go fail exam', 0),
#  179: ('oh good know could messag friend hello ai', 4),
#  180: ('know special special olymp wo let compet event', 0),
#  181: ('day half late suppos lesson day believ verbal written confirm unit',
#   0),
#  182: ('wonder investig determin inflat head', 2),
#  183: ('let check new comment', 0),
#  184: ('get readi go watch night museum dum dum give gum gum', 2),
#  185: ('god sho love feel realli realli bless tonight', 4),
#  186: ('discov love easter craft egg hot cross bun feel like watch princ aid easter medit',
#   4),
#  187: ('excit see bobbi flay guy tomorrow great food music fest', 4),
#  188: ('could excit car', 4),
#  189: ('miss twitter rude peopl remov like tweet bitchfuck', 0),
#  190: ('learn lambda calculu', 4),
#  191: ('cartoon newspap ever regard twitter', 4),
#  192: ('ride around car see year', 4),
#  193: ('ball perfect', 2),
#  194: ('tell give use program support unemploy', 0),
#  195: ('weka bug spent almost two hour find', 0),
#  196: ('student back trip china silver spring high school class trip china en',
#   2),
#  197: ('via', 2),
#  198: ('someth enjoy make happi', 4),
#  199: ('eat home made', 2),
#  200: ('idiot would ride driverless car', 0),
#  201: ('way mani assign due', 0),
#  202: ('new best friend', 4),
#  203: ('got joke got watch bit dinner speech last night love presid', 4),
#  204: ('alreadi run spot bedroom', 4),
#  205: ('normal weight get normal eat', 2),
#  206: ('big go home', 0),
#  207: ('today girl bean total thought loud', 0),
#  208: ('ugh amount time stupid insect bitten grr', 0),
#  209: ('think memori card least one guess', 0),
#  210: ('ye tell hubbi go get sum mcdonald', 4),
#  211: ('murder', 4),
#  212: ('air khaki pink releas', 2),
#  213: ('found stapl', 2),
#  214: ('car citi street cannot wait technolog avail consum', 4),
#  215: ('mountain view would see priu larg roof rack think look car', 2),
#  216: ('hey famili question trip world pleas follow could guy', 2),
#  217: ('saw car life complet', 4),
#  218: ('adob commerci', 2),
#  219: ('would like go drive guy driverless car car ever', 4),
#  220: ('vision packag driverless car humanoid robot happen drone bs', 2),
#  221: ('point tweet still found search twitter pleas fix thank bye', 0),
#  222: ('wrote entir stori save', 0),
#  223: ('way bed weird hope good morn', 4),
#  224: ('driverless car seem way given infrastructur challeng pilotless plane seem much doabl',
#   0),
#  225: ('track social media', 2),
#  226: ('car still mani flaw via', 0),
#  227: ('ca wait driverless car come first time excit motor vehicl entir life',
#   4),
#  228: ('good point draw nice quot though like', 4),
#  229: ('time warner road runner custom support absolut blow hate net option readi go nuclear',
#   0),
#  230: ('like piss thing like car robber baron throw silver dollar offic window',
#   0),
#  231: ('told think get sick goe give', 2),
#  232: ('train club beta look interest', 4),
#  233: ('hate select green tea bought two carton wast money', 0),
#  234: ('fantast invest futur beat', 2),
#  235: ('battl appeas passeng wall street republican', 2),
#  236: ('creat fake market new movi viral market best', 4),
#  237: ('time warner realli pick bad time work want get watch hill', 0),
#  238: ('ye week pretti happi result', 4),
#  239: ('tomorrow late day thank good', 4),
#  240: ('good keep connect board ten minut open get plane land hour late flight',
#   0),
#  241: ('eat cake', 2),
#  242: ('sound like good idea', 4),
#  243: ('burn cash stop financi tsunami mean take handout', 0),
#  244: ('go see star trek soon dad', 2),
#  245: ('safari fast even', 0),
#  246: ('flew back great crew servic leg thank', 4),
#  247: ('man work', 0),
#  248: ('good good sleep', 4),
#  249: ('give weka engin interfac bird strike data test given', 2),
#  250: ('life bitch dick', 0),
#  251: ('car one drive today', 2),
#  252: ('yahoo answer butt sometim', 0),
#  253: ('real surpris somehow involv', 2),
#  254: ('north pleas ceas china even like', 0),
#  255: ('want driverless car bad', 4),
#  256: ('driverless car take us wrong spot say damn robot agre board bu', 0),
#  257: ('idol love repli', 4),
#  258: ('dentist wrong wrong', 0),
#  259: ('tri', 4),
#  260: ('basebal prospect', 2),
#  261: ('got nice ted well steadi work go guy investig', 2),
#  262: ('earli', 0),
#  263: ('go dentist late', 0),
#  264: ('look aw lot like one privat jet', 2),
#  265: ('thought car must manual overrid type', 2),
#  266: ('watch life geeki histori', 2),
#  267: ('love read tweet would nice see love mug read pictur', 4),
#  268: ('driverless car think rest craze drunk driver road societi today', 0),
#  269: ('saw night museum sheer desper movi', 0),
#  270: ('warren buffet economi', 2),
#  271: ('thank pleas also mention breakfast chicken dinner entre accompani truli first class',
#   4),
#  272: ('driverless car caus crash two peopl injur', 0),
#  273: ('awesom viral market funni peopl', 4),
#  274: ('loung around eat bell watch nci work tonight need help awak', 2),
#  275: ('wrist still hurt get hate dentist scari place time watch eagl eye want join',
#   4),
#  276: ('ever amaz partner go play effect', 4),
#  277: ('absolut hilari', 4),
#  278: ('saw car', 2),
#  279: ('favorit', 0),
#  280: ('got rid stupid time warner today take nap roomi cook pretti good end',
#   0),
#  281: ('laker great cannot wait night laker vs', 4),
#  282: ('would realli live east alto could guess summer', 0),
#  283: ('time warner cabl phone rep nail ugh cabl work min ago', 0),
#  284: ('day market happi stock', 4),
#  285: ('hi great hear see cruis cannot wait hope well knight bu', 4),
#  286: ('coupon code expir soon', 2),
#  287: ('own playoff ad', 2),
#  288: ('shame forc make car white hous think sell think', 0),
#  289: ('eat', 2),
#  290: ('fan crazi inde', 0),
#  291: ('sick worri chug thing place', 0),
#  292: ('dad day ate mesa grill last night met bobbi flay much fun except complet lost voic today',
#   4),
#  293: ('awesom idea continu learn program kindl', 4),
#  294: ('talk cheap bing stick', 0),
#  295: ('well alway stumbl greatli wast countless hour life', 4),
#  296: ('stop lunch mcdonald chicken nuggetsss', 4),
#  297: ('super investor great weekend read warren buffet', 4)}

# %%
Prep_tweets = pd.DataFrame.from_dict(new_tweets, orient='index',columns=['Tweet','Senti_val'])

# %%
#View as a new DFrame
Prep_tweets.tail(15)
# Out:
#                                                  Tweet  Senti_val
# 283  time warner cabl phone rep nail ugh cabl work ...          0
# 284                             day market happi stock          4
# 285  hi great hear see cruis cannot wait hope well ...          4
# 286                             coupon code expir soon          2
# 287                                     own playoff ad          2
# 288    shame forc make car white hous think sell think          0
# 289                                                eat          2
# 290                                     fan crazi inde          0
# 291                        sick worri chug thing place          0
# 292  dad day ate mesa grill last night met bobbi fl...          4
# 293            awesom idea continu learn program kindl          4
# 294                              talk cheap bing stick          0
# 295  well alway stumbl greatli wast countless hour ...          4
# 296              stop lunch mcdonald chicken nuggetsss          4
# 297    super investor great weekend read warren buffet          4
